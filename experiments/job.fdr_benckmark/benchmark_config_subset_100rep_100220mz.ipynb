# %%
import scanpy as sc
import pandas as pd
import numpy as np
import scipy as sp
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
from gprofiler import GProfiler

# scTRS tools
import scTRS.util as util
import scTRS.data_loader as dl
import scTRS.method as md

# autoreload
# %load_ext autoreload
# %autoreload 2
# logging
sc.logging.print_versions()
# Out:
# scanpy==1.5.1 anndata==0.7.4 umap==0.4.6 numpy==1.19.0 scipy==1.5.1 pandas==1.0.5 scikit-learn==0.23.1 statsmodels==0.11.1

# %%
# Setup file paths
DATA_PATH = '/n/holystore01/LABS/price_lab/Users/mjzhang/scTRS_data'
# Please change this to your own path
RESULT_PATH = '/n/home11/mjzhang/gwas_informed_scRNAseq/results'

# %% [markdown]
# ### Load TMS data

# %%
# Count data (used for scoring genes)
start_time = time.time()
data_facs_ct = dl.load_tms_ct(DATA_PATH, data_name='facs')
print('# TMS facs count data: n_cell=%d, n_gene=%d'
      %(data_facs_ct.shape[0], data_facs_ct.shape[1]))
sc.pp.subsample(data_facs_ct, n_obs=20000, random_state=0, copy=False)
print('# Subsampled TMS facs count data: n_cell=%d, n_gene=%d'
      %(data_facs_ct.shape[0], data_facs_ct.shape[1]))
print('# time=%0.1fs'%(time.time() - start_time))
# Out:
# Trying to set attribute `.obs` of view, copying.
# # TMS facs count data: n_cell=110096, n_gene=22966
# # Subsampled TMS facs count data: n_cell=20000, n_gene=22966
# # time=19.1s

# %% [markdown]
# ### Compute TRS

# %%
# Precompute mean and var 
md.compute_stats(data_facs_ct)

# %%
# Obtain TRS: This takes a lot of time.
from itertools import product

DATA_PATH='/n/holystore01/LABS/price_lab/Users/mjzhang/scTRS_data'
simu_list = [x.replace('_rep1','') for x in os.listdir(DATA_PATH+'/data_null_geneset') if x[-5:]=='_rep1']
simu_list.sort()
n_rep=100

start_time = time.time()
dic_trs={}

md_list = [['mean_match', 'mean', 'empi'],
           ['mean_match', 'mean', 'recipe_vision'],
           ['mean_match', 'vst', 'empi'],
           ['mean_match', 'vst', 'recipe_vision']]

for simu in simu_list:
    for i_rep in np.arange(n_rep):
        
        trait = '%s_rep%d'%(simu,i_rep)
        temp_df = pd.read_csv(DATA_PATH+'/data_null_geneset/'+trait, sep='\t')
        
        print('# %-30s time=%0.1fs'%(trait,time.time()-start_time))
        
        for ctrl_opt,trs_opt,bc_opt in md_list:
            
            # Equal weight
            md.score_cell(data_facs_ct, temp_df['gene'].values, suffix='', 
                          ctrl_opt=ctrl_opt, trs_opt=trs_opt, bc_opt=bc_opt,
                          n_ctrl=1, n_genebin=200, 
                          return_list=['trs_ep'], verbose=False)
            term='%s_equal;ctrl_opt=%s,trs_opt=%s,bc_opt=%s'%(trait,ctrl_opt,trs_opt,bc_opt)
            dic_trs[term] = data_facs_ct.obs['trs_ep'].values.copy()

            # Uniform weight
            md.score_cell(data_facs_ct, temp_df['gene'].values, 
                          gene_weight=temp_df['gene_weight.unif'].values, suffix='', 
                          ctrl_opt=ctrl_opt, trs_opt=trs_opt, bc_opt=bc_opt,
                          n_ctrl=1, n_genebin=200, 
                          return_list=['trs_ep'], verbose=False)
            term='%s_unif;ctrl_opt=%s,trs_opt=%s,bc_opt=%s'%(trait,ctrl_opt,trs_opt,bc_opt)
            dic_trs[term] = data_facs_ct.obs['trs_ep'].values.copy()

            # Normal weight
            md.score_cell(data_facs_ct, temp_df['gene'].values, 
                          gene_weight=temp_df['gene_weight.normal'].values, suffix='', 
                          ctrl_opt=ctrl_opt, trs_opt=trs_opt, bc_opt=bc_opt,
                          n_ctrl=1, n_genebin=200, 
                          return_list=['trs_ep'], verbose=False)
            term='%s_norm;ctrl_opt=%s,trs_opt=%s,bc_opt=%s'%(trait,ctrl_opt,trs_opt,bc_opt)
            dic_trs[term] = data_facs_ct.obs['trs_ep'].values.copy()
# Out:
# # all_size100_rep0               time=0.0s
# # all_size100_rep1               time=8.4s
# # all_size100_rep2               time=16.5s
# # all_size100_rep3               time=24.8s
# # all_size100_rep4               time=33.2s
# # all_size100_rep5               time=41.4s
# # all_size100_rep6               time=49.5s
# # all_size100_rep7               time=57.7s
# # all_size100_rep8               time=65.9s
# # all_size100_rep9               time=74.0s
# # all_size100_rep10              time=82.2s
# # all_size100_rep11              time=90.3s
# # all_size100_rep12              time=98.5s
# # all_size100_rep13              time=106.8s
# # all_size100_rep14              time=115.0s
# # all_size100_rep15              time=123.4s
# # all_size100_rep16              time=131.6s
# # all_size100_rep17              time=139.9s
# # all_size100_rep18              time=148.1s
# # all_size100_rep19              time=156.4s
# # all_size100_rep20              time=164.7s
# # all_size100_rep21              time=173.2s
# # all_size100_rep22              time=181.5s
# # all_size100_rep23              time=189.5s
# # all_size100_rep24              time=197.7s
# # all_size100_rep25              time=206.0s
# # all_size100_rep26              time=214.1s
# # all_size100_rep27              time=222.3s
# # all_size100_rep28              time=230.6s
# # all_size100_rep29              time=238.7s
# # all_size100_rep30              time=246.9s
# # all_size100_rep31              time=255.1s
# # all_size100_rep32              time=263.3s
# # all_size100_rep33              time=271.6s
# # all_size100_rep34              time=279.8s
# # all_size100_rep35              time=288.2s
# # all_size100_rep36              time=296.5s
# # all_size100_rep37              time=304.5s
# # all_size100_rep38              time=312.5s
# # all_size100_rep39              time=320.6s
# # all_size100_rep40              time=328.9s
# # all_size100_rep41              time=337.0s
# # all_size100_rep42              time=345.3s
# # all_size100_rep43              time=353.5s
# # all_size100_rep44              time=361.8s
# # all_size100_rep45              time=369.8s
# # all_size100_rep46              time=378.1s
# # all_size100_rep47              time=386.3s
# # all_size100_rep48              time=394.8s
# # all_size100_rep49              time=402.8s
# # all_size100_rep50              time=411.0s
# # all_size100_rep51              time=419.2s
# # all_size100_rep52              time=427.4s
# # all_size100_rep53              time=435.7s
# # all_size100_rep54              time=444.0s
# # all_size100_rep55              time=452.3s
# # all_size100_rep56              time=460.6s
# # all_size100_rep57              time=468.8s
# # all_size100_rep58              time=477.2s
# # all_size100_rep59              time=485.5s
# # all_size100_rep60              time=493.7s
# # all_size100_rep61              time=502.1s
# # all_size100_rep62              time=510.3s
# # all_size100_rep63              time=518.6s
# # all_size100_rep64              time=526.8s
# # all_size100_rep65              time=535.1s
# # all_size100_rep66              time=543.4s
# # all_size100_rep67              time=551.7s
# # all_size100_rep68              time=559.8s
# # all_size100_rep69              time=568.1s
# # all_size100_rep70              time=576.1s
# # all_size100_rep71              time=584.2s
# # all_size100_rep72              time=592.5s
# # all_size100_rep73              time=600.5s
# # all_size100_rep74              time=608.4s
# # all_size100_rep75              time=616.5s
# # all_size100_rep76              time=624.8s
# # all_size100_rep77              time=633.4s
# # all_size100_rep78              time=641.6s
# # all_size100_rep79              time=649.7s
# # all_size100_rep80              time=658.0s
# # all_size100_rep81              time=666.1s
# # all_size100_rep82              time=674.2s
# # all_size100_rep83              time=682.5s
# # all_size100_rep84              time=690.7s
# # all_size100_rep85              time=698.8s
# # all_size100_rep86              time=706.9s
# # all_size100_rep87              time=715.1s
# # all_size100_rep88              time=723.2s
# # all_size100_rep89              time=731.2s
# # all_size100_rep90              time=739.6s
# # all_size100_rep91              time=747.9s
# # all_size100_rep92              time=756.3s
# # all_size100_rep93              time=764.5s
# # all_size100_rep94              time=772.6s
# # all_size100_rep95              time=781.0s
# # all_size100_rep96              time=789.0s
# # all_size100_rep97              time=797.0s
# # all_size100_rep98              time=805.2s
# # all_size100_rep99              time=813.3s
# # all_size20_rep0                time=821.5s
# # all_size20_rep1                time=828.3s
# # all_size20_rep2                time=835.0s
# # all_size20_rep3                time=841.8s
# # all_size20_rep4                time=848.6s
# # all_size20_rep5                time=855.4s
# # all_size20_rep6                time=862.2s
# # all_size20_rep7                time=869.1s
# # all_size20_rep8                time=875.9s
# # all_size20_rep9                time=882.5s
# # all_size20_rep10               time=889.3s
# # all_size20_rep11               time=896.0s
# # all_size20_rep12               time=902.7s
# # all_size20_rep13               time=909.5s
# # all_size20_rep14               time=916.3s
# # all_size20_rep15               time=923.1s
# # all_size20_rep16               time=929.9s
# # all_size20_rep17               time=936.8s
# # all_size20_rep18               time=943.6s
# # all_size20_rep19               time=950.5s
# # all_size20_rep20               time=957.3s
# # all_size20_rep21               time=964.1s
# # all_size20_rep22               time=971.0s
# # all_size20_rep23               time=977.8s
# # all_size20_rep24               time=984.6s
# # all_size20_rep25               time=991.5s
# # all_size20_rep26               time=998.3s
# # all_size20_rep27               time=1005.1s
# # all_size20_rep28               time=1012.2s
# # all_size20_rep29               time=1019.1s
# # all_size20_rep30               time=1025.9s
# # all_size20_rep31               time=1032.7s
# # all_size20_rep32               time=1039.5s
# # all_size20_rep33               time=1046.4s
# # all_size20_rep34               time=1053.2s
# # all_size20_rep35               time=1060.0s
# # all_size20_rep36               time=1066.8s
# # all_size20_rep37               time=1073.6s
# # all_size20_rep38               time=1080.4s
# # all_size20_rep39               time=1087.3s
# # all_size20_rep40               time=1094.1s
# # all_size20_rep41               time=1101.0s
# # all_size20_rep42               time=1107.8s
# # all_size20_rep43               time=1114.8s
# # all_size20_rep44               time=1121.7s
# # all_size20_rep45               time=1128.4s
# # all_size20_rep46               time=1135.2s
# # all_size20_rep47               time=1142.1s
# # all_size20_rep48               time=1149.0s
# # all_size20_rep49               time=1155.8s
# # all_size20_rep50               time=1162.6s
# # all_size20_rep51               time=1169.5s
# # all_size20_rep52               time=1176.4s
# # all_size20_rep53               time=1183.2s
# # all_size20_rep54               time=1190.0s
# # all_size20_rep55               time=1197.0s
# # all_size20_rep56               time=1203.7s
# # all_size20_rep57               time=1210.6s
# # all_size20_rep58               time=1217.4s
# # all_size20_rep59               time=1224.3s
# # all_size20_rep60               time=1231.2s
# # all_size20_rep61               time=1238.0s
# # all_size20_rep62               time=1244.9s
# # all_size20_rep63               time=1251.7s
# # all_size20_rep64               time=1258.6s
# # all_size20_rep65               time=1265.7s
# # all_size20_rep66               time=1272.6s
# # all_size20_rep67               time=1279.5s
# # all_size20_rep68               time=1286.3s
# # all_size20_rep69               time=1293.2s
# # all_size20_rep70               time=1300.2s
# # all_size20_rep71               time=1307.0s
# # all_size20_rep72               time=1313.9s
# # all_size20_rep73               time=1320.9s
# # all_size20_rep74               time=1327.7s
# # all_size20_rep75               time=1334.6s
# # all_size20_rep76               time=1341.5s
# # all_size20_rep77               time=1348.3s
# # all_size20_rep78               time=1355.2s
# # all_size20_rep79               time=1362.2s
# # all_size20_rep80               time=1369.0s
# # all_size20_rep81               time=1376.0s
# # all_size20_rep82               time=1382.7s
# # all_size20_rep83               time=1389.5s
# # all_size20_rep84               time=1396.5s
# # all_size20_rep85               time=1403.3s
# # all_size20_rep86               time=1410.2s
# # all_size20_rep87               time=1417.1s
# # all_size20_rep88               time=1424.1s
# # all_size20_rep89               time=1431.0s
# # all_size20_rep90               time=1437.7s
# # all_size20_rep91               time=1444.7s
# # all_size20_rep92               time=1451.7s
# # all_size20_rep93               time=1458.6s
# # all_size20_rep94               time=1465.5s
# # all_size20_rep95               time=1472.5s
# # all_size20_rep96               time=1479.5s
# # all_size20_rep97               time=1486.5s
# # all_size20_rep98               time=1493.3s
# # all_size20_rep99               time=1500.2s
# # all_size500_rep0               time=1507.0s
# # all_size500_rep1               time=1518.5s
# # all_size500_rep2               time=1529.9s
# # all_size500_rep3               time=1541.2s
# # all_size500_rep4               time=1552.2s
# # all_size500_rep5               time=1563.6s
# # all_size500_rep6               time=1575.0s
# # all_size500_rep7               time=1586.7s
# # all_size500_rep8               time=1598.2s
# # all_size500_rep9               time=1609.6s
# # all_size500_rep10              time=1621.0s
# # all_size500_rep11              time=1632.2s
# # all_size500_rep12              time=1643.6s
# # all_size500_rep13              time=1655.0s
# # all_size500_rep14              time=1666.4s
# # all_size500_rep15              time=1677.8s
# # all_size500_rep16              time=1689.1s
# # all_size500_rep17              time=1700.2s
# # all_size500_rep18              time=1711.3s
# # all_size500_rep19              time=1722.6s
# # all_size500_rep20              time=1733.8s
# # all_size500_rep21              time=1744.9s
# # all_size500_rep22              time=1756.2s
# # all_size500_rep23              time=1767.7s
# # all_size500_rep24              time=1779.0s
# # all_size500_rep25              time=1790.3s
# # all_size500_rep26              time=1801.8s
# # all_size500_rep27              time=1813.2s
# # all_size500_rep28              time=1825.0s
# # all_size500_rep29              time=1836.3s
# # all_size500_rep30              time=1847.4s
# # all_size500_rep31              time=1858.7s
# # all_size500_rep32              time=1870.2s
# # all_size500_rep33              time=1881.3s
# # all_size500_rep34              time=1892.7s
# # all_size500_rep35              time=1903.8s
# # all_size500_rep36              time=1915.1s
# # all_size500_rep37              time=1926.6s
# # all_size500_rep38              time=1938.0s
# # all_size500_rep39              time=1949.1s
# # all_size500_rep40              time=1960.2s
# # all_size500_rep41              time=1971.2s
# # all_size500_rep42              time=1982.5s
# # all_size500_rep43              time=1993.7s
# # all_size500_rep44              time=2004.8s
# # all_size500_rep45              time=2016.1s
# # all_size500_rep46              time=2027.2s
# # all_size500_rep47              time=2038.6s
# # all_size500_rep48              time=2049.7s
# # all_size500_rep49              time=2060.9s
# # all_size500_rep50              time=2072.1s
# # all_size500_rep51              time=2083.1s
# # all_size500_rep52              time=2094.0s
# # all_size500_rep53              time=2105.1s
# # all_size500_rep54              time=2116.1s
# # all_size500_rep55              time=2123.1s
# # all_size500_rep56              time=2129.3s
# # all_size500_rep57              time=2134.8s
# # all_size500_rep58              time=2140.4s
# # all_size500_rep59              time=2145.9s
# # all_size500_rep60              time=2151.4s
# # all_size500_rep61              time=2156.9s
# # all_size500_rep62              time=2162.4s
# # all_size500_rep63              time=2167.8s
# # all_size500_rep64              time=2173.4s
# # all_size500_rep65              time=2178.9s
# # all_size500_rep66              time=2184.5s
# # all_size500_rep67              time=2190.1s
# # all_size500_rep68              time=2195.7s
# # all_size500_rep69              time=2201.1s
# # all_size500_rep70              time=2206.6s
# # all_size500_rep71              time=2212.1s
# # all_size500_rep72              time=2217.7s
# # all_size500_rep73              time=2223.2s
# # all_size500_rep74              time=2228.8s
# # all_size500_rep75              time=2234.4s
# # all_size500_rep76              time=2239.9s
# # all_size500_rep77              time=2245.4s
# # all_size500_rep78              time=2251.0s
# # all_size500_rep79              time=2256.5s
# # all_size500_rep80              time=2262.0s
# # all_size500_rep81              time=2267.5s
# # all_size500_rep82              time=2273.2s
# # all_size500_rep83              time=2278.7s
# # all_size500_rep84              time=2284.3s
# # all_size500_rep85              time=2290.0s
# # all_size500_rep86              time=2295.5s
# # all_size500_rep87              time=2301.0s
# # all_size500_rep88              time=2306.5s
# # all_size500_rep89              time=2312.0s
# # all_size500_rep90              time=2317.5s
# # all_size500_rep91              time=2323.0s
# # all_size500_rep92              time=2328.6s
# # all_size500_rep93              time=2334.1s
# # all_size500_rep94              time=2339.6s
# # all_size500_rep95              time=2345.2s
# # all_size500_rep96              time=2350.8s
# # all_size500_rep97              time=2356.4s
# # all_size500_rep98              time=2361.9s
# # all_size500_rep99              time=2367.4s
# # highexp_size100_rep0           time=2373.0s
# # highexp_size100_rep1           time=2377.4s
# # highexp_size100_rep2           time=2381.8s
# # highexp_size100_rep3           time=2386.2s
# # highexp_size100_rep4           time=2390.6s
# # highexp_size100_rep5           time=2395.0s
# # highexp_size100_rep6           time=2399.4s
# # highexp_size100_rep7           time=2403.8s
# # highexp_size100_rep8           time=2408.2s
# # highexp_size100_rep9           time=2412.5s
# # highexp_size100_rep10          time=2416.9s
# # highexp_size100_rep11          time=2421.3s
# # highexp_size100_rep12          time=2425.7s
# # highexp_size100_rep13          time=2430.1s
# # highexp_size100_rep14          time=2434.5s
# # highexp_size100_rep15          time=2438.9s
# # highexp_size100_rep16          time=2443.2s
# # highexp_size100_rep17          time=2447.6s
# # highexp_size100_rep18          time=2452.0s
# # highexp_size100_rep19          time=2456.4s
# # highexp_size100_rep20          time=2460.8s
# # highexp_size100_rep21          time=2465.2s
# # highexp_size100_rep22          time=2469.7s
# # highexp_size100_rep23          time=2474.2s
# # highexp_size100_rep24          time=2478.6s
# # highexp_size100_rep25          time=2483.1s
# # highexp_size100_rep26          time=2487.5s
# # highexp_size100_rep27          time=2491.9s
# # highexp_size100_rep28          time=2496.4s
# # highexp_size100_rep29          time=2500.8s
# # highexp_size100_rep30          time=2505.2s
# # highexp_size100_rep31          time=2509.5s
# # highexp_size100_rep32          time=2514.0s
# # highexp_size100_rep33          time=2518.3s
# # highexp_size100_rep34          time=2522.7s
# # highexp_size100_rep35          time=2527.1s
# # highexp_size100_rep36          time=2531.5s
# # highexp_size100_rep37          time=2535.9s
# # highexp_size100_rep38          time=2540.4s
# # highexp_size100_rep39          time=2544.8s
# # highexp_size100_rep40          time=2549.2s
# # highexp_size100_rep41          time=2553.7s
# # highexp_size100_rep42          time=2558.1s
# # highexp_size100_rep43          time=2562.5s
# # highexp_size100_rep44          time=2567.0s
# # highexp_size100_rep45          time=2571.4s
# # highexp_size100_rep46          time=2575.9s
# # highexp_size100_rep47          time=2580.3s
# # highexp_size100_rep48          time=2584.7s
# # highexp_size100_rep49          time=2589.1s
# # highexp_size100_rep50          time=2593.5s
# # highexp_size100_rep51          time=2597.9s
# # highexp_size100_rep52          time=2602.3s
# # highexp_size100_rep53          time=2606.8s
# # highexp_size100_rep54          time=2611.2s
# # highexp_size100_rep55          time=2615.5s
# # highexp_size100_rep56          time=2620.0s
# # highexp_size100_rep57          time=2624.4s
# # highexp_size100_rep58          time=2628.8s
# # highexp_size100_rep59          time=2633.3s
# # highexp_size100_rep60          time=2637.8s
# # highexp_size100_rep61          time=2642.3s
# # highexp_size100_rep62          time=2646.8s
# # highexp_size100_rep63          time=2651.2s
# # highexp_size100_rep64          time=2655.7s
# # highexp_size100_rep65          time=2660.2s
# # highexp_size100_rep66          time=2664.6s
# # highexp_size100_rep67          time=2669.0s
# # highexp_size100_rep68          time=2673.4s
# # highexp_size100_rep69          time=2677.8s
# # highexp_size100_rep70          time=2682.2s
# # highexp_size100_rep71          time=2686.6s
# # highexp_size100_rep72          time=2690.9s
# # highexp_size100_rep73          time=2695.4s
# # highexp_size100_rep74          time=2699.8s
# # highexp_size100_rep75          time=2704.2s
# # highexp_size100_rep76          time=2708.6s
# # highexp_size100_rep77          time=2713.1s
# # highexp_size100_rep78          time=2717.5s
# # highexp_size100_rep79          time=2721.9s
# # highexp_size100_rep80          time=2726.3s
# # highexp_size100_rep81          time=2730.7s
# # highexp_size100_rep82          time=2735.1s
# # highexp_size100_rep83          time=2739.6s
# # highexp_size100_rep84          time=2743.9s
# # highexp_size100_rep85          time=2748.4s
# # highexp_size100_rep86          time=2752.8s
# # highexp_size100_rep87          time=2757.3s
# # highexp_size100_rep88          time=2761.7s
# # highexp_size100_rep89          time=2766.1s
# # highexp_size100_rep90          time=2770.5s
# # highexp_size100_rep91          time=2774.8s
# # highexp_size100_rep92          time=2779.3s
# # highexp_size100_rep93          time=2783.6s
# # highexp_size100_rep94          time=2788.0s
# # highexp_size100_rep95          time=2792.5s
# # highexp_size100_rep96          time=2796.9s
# # highexp_size100_rep97          time=2801.4s
# # highexp_size100_rep98          time=2805.8s
# # highexp_size100_rep99          time=2810.3s
# # highexp_size20_rep0            time=2814.7s
# # highexp_size20_rep1            time=2818.3s
# # highexp_size20_rep2            time=2822.0s
# # highexp_size20_rep3            time=2825.5s
# # highexp_size20_rep4            time=2829.1s
# # highexp_size20_rep5            time=2832.7s
# # highexp_size20_rep6            time=2836.2s
# # highexp_size20_rep7            time=2839.8s
# # highexp_size20_rep8            time=2843.4s
# # highexp_size20_rep9            time=2847.0s
# # highexp_size20_rep10           time=2850.6s
# # highexp_size20_rep11           time=2854.2s
# # highexp_size20_rep12           time=2857.7s
# # highexp_size20_rep13           time=2861.4s
# # highexp_size20_rep14           time=2864.9s
# # highexp_size20_rep15           time=2868.6s
# # highexp_size20_rep16           time=2872.1s
# # highexp_size20_rep17           time=2875.8s
# # highexp_size20_rep18           time=2879.3s
# # highexp_size20_rep19           time=2882.9s
# # highexp_size20_rep20           time=2886.4s
# # highexp_size20_rep21           time=2890.0s
# # highexp_size20_rep22           time=2893.5s
# # highexp_size20_rep23           time=2897.1s
# # highexp_size20_rep24           time=2900.7s
# # highexp_size20_rep25           time=2904.3s
# # highexp_size20_rep26           time=2907.8s
# # highexp_size20_rep27           time=2911.5s
# # highexp_size20_rep28           time=2915.0s
# # highexp_size20_rep29           time=2918.6s
# # highexp_size20_rep30           time=2922.3s
# # highexp_size20_rep31           time=2925.8s
# # highexp_size20_rep32           time=2929.4s
# # highexp_size20_rep33           time=2933.0s
# # highexp_size20_rep34           time=2936.6s
# # highexp_size20_rep35           time=2940.2s
# # highexp_size20_rep36           time=2943.7s
# # highexp_size20_rep37           time=2947.4s
# # highexp_size20_rep38           time=2951.0s
# # highexp_size20_rep39           time=2954.6s
# # highexp_size20_rep40           time=2958.3s
# # highexp_size20_rep41           time=2961.8s
# # highexp_size20_rep42           time=2965.4s
# # highexp_size20_rep43           time=2969.0s
# # highexp_size20_rep44           time=2972.6s
# # highexp_size20_rep45           time=2976.2s
# # highexp_size20_rep46           time=2979.7s
# # highexp_size20_rep47           time=2983.3s
# # highexp_size20_rep48           time=2986.9s
# # highexp_size20_rep49           time=2990.5s
# # highexp_size20_rep50           time=2994.0s
# # highexp_size20_rep51           time=2997.6s
# # highexp_size20_rep52           time=3001.3s
# # highexp_size20_rep53           time=3004.9s
# # highexp_size20_rep54           time=3008.4s
# # highexp_size20_rep55           time=3012.0s
# # highexp_size20_rep56           time=3015.6s
# # highexp_size20_rep57           time=3019.2s
# # highexp_size20_rep58           time=3022.8s
# # highexp_size20_rep59           time=3026.3s
# # highexp_size20_rep60           time=3029.9s
# # highexp_size20_rep61           time=3033.5s
# # highexp_size20_rep62           time=3037.1s
# # highexp_size20_rep63           time=3040.6s
# # highexp_size20_rep64           time=3044.2s
# # highexp_size20_rep65           time=3047.8s
# # highexp_size20_rep66           time=3051.4s
# # highexp_size20_rep67           time=3055.1s
# # highexp_size20_rep68           time=3058.7s
# # highexp_size20_rep69           time=3062.2s
# # highexp_size20_rep70           time=3065.9s
# # highexp_size20_rep71           time=3069.4s
# # highexp_size20_rep72           time=3073.0s
# # highexp_size20_rep73           time=3076.6s
# # highexp_size20_rep74           time=3080.2s
# # highexp_size20_rep75           time=3083.8s
# # highexp_size20_rep76           time=3087.3s
# # highexp_size20_rep77           time=3090.9s
# # highexp_size20_rep78           time=3094.5s
# # highexp_size20_rep79           time=3098.0s
# # highexp_size20_rep80           time=3101.7s
# # highexp_size20_rep81           time=3105.2s
# # highexp_size20_rep82           time=3108.9s
# # highexp_size20_rep83           time=3112.5s
# # highexp_size20_rep84           time=3116.1s
# # highexp_size20_rep85           time=3119.6s
# # highexp_size20_rep86           time=3123.2s
# # highexp_size20_rep87           time=3126.8s
# # highexp_size20_rep88           time=3130.4s
# # highexp_size20_rep89           time=3134.0s
# # highexp_size20_rep90           time=3137.5s
# # highexp_size20_rep91           time=3141.1s
# # highexp_size20_rep92           time=3144.6s
# # highexp_size20_rep93           time=3148.2s
# # highexp_size20_rep94           time=3151.8s
# # highexp_size20_rep95           time=3155.5s
# # highexp_size20_rep96           time=3159.1s
# # highexp_size20_rep97           time=3162.7s
# # highexp_size20_rep98           time=3166.3s
# # highexp_size20_rep99           time=3169.8s
# # highexp_size500_rep0           time=3173.4s
# # highexp_size500_rep1           time=3178.6s
# # highexp_size500_rep2           time=3183.8s
# # highexp_size500_rep3           time=3189.0s
# # highexp_size500_rep4           time=3194.1s
# # highexp_size500_rep5           time=3199.3s
# # highexp_size500_rep6           time=3204.5s
# # highexp_size500_rep7           time=3209.6s
# # highexp_size500_rep8           time=3214.8s
# # highexp_size500_rep9           time=3220.0s
# # highexp_size500_rep10          time=3225.0s
# # highexp_size500_rep11          time=3230.0s
# # highexp_size500_rep12          time=3235.3s
# # highexp_size500_rep13          time=3240.6s
# # highexp_size500_rep14          time=3245.8s
# # highexp_size500_rep15          time=3250.7s
# # highexp_size500_rep16          time=3255.6s
# # highexp_size500_rep17          time=3260.6s
# # highexp_size500_rep18          time=3265.6s
# # highexp_size500_rep19          time=3270.7s
# # highexp_size500_rep20          time=3275.6s
# # highexp_size500_rep21          time=3280.6s
# # highexp_size500_rep22          time=3285.7s
# # highexp_size500_rep23          time=3290.7s
# # highexp_size500_rep24          time=3295.7s
# # highexp_size500_rep25          time=3300.9s
# # highexp_size500_rep26          time=3305.7s
# # highexp_size500_rep27          time=3310.6s
# # highexp_size500_rep28          time=3315.6s
# # highexp_size500_rep29          time=3320.6s
# # highexp_size500_rep30          time=3325.4s
# # highexp_size500_rep31          time=3330.2s
# # highexp_size500_rep32          time=3335.1s
# # highexp_size500_rep33          time=3340.1s
# # highexp_size500_rep34          time=3345.1s
# # highexp_size500_rep35          time=3349.9s
# # highexp_size500_rep36          time=3354.7s
# # highexp_size500_rep37          time=3359.7s
# # highexp_size500_rep38          time=3364.7s
# # highexp_size500_rep39          time=3369.7s
# # highexp_size500_rep40          time=3374.8s
# # highexp_size500_rep41          time=3379.8s
# # highexp_size500_rep42          time=3384.6s
# # highexp_size500_rep43          time=3389.6s
# # highexp_size500_rep44          time=3394.5s
# # highexp_size500_rep45          time=3399.6s
# # highexp_size500_rep46          time=3404.4s
# # highexp_size500_rep47          time=3409.3s
# # highexp_size500_rep48          time=3414.2s
# # highexp_size500_rep49          time=3419.1s
# # highexp_size500_rep50          time=3424.1s
# # highexp_size500_rep51          time=3429.1s
# # highexp_size500_rep52          time=3433.9s
# # highexp_size500_rep53          time=3438.9s
# # highexp_size500_rep54          time=3443.8s
# # highexp_size500_rep55          time=3448.6s
# # highexp_size500_rep56          time=3453.7s
# # highexp_size500_rep57          time=3458.5s
# # highexp_size500_rep58          time=3463.5s
# # highexp_size500_rep59          time=3468.5s
# # highexp_size500_rep60          time=3473.4s
# # highexp_size500_rep61          time=3478.4s
# # highexp_size500_rep62          time=3483.3s
# # highexp_size500_rep63          time=3488.1s
# # highexp_size500_rep64          time=3493.1s
# # highexp_size500_rep65          time=3498.0s
# # highexp_size500_rep66          time=3502.8s
# # highexp_size500_rep67          time=3507.9s
# # highexp_size500_rep68          time=3512.9s
# # highexp_size500_rep69          time=3517.8s
# # highexp_size500_rep70          time=3522.8s
# # highexp_size500_rep71          time=3527.9s
# # highexp_size500_rep72          time=3533.1s
# # highexp_size500_rep73          time=3538.2s
# # highexp_size500_rep74          time=3543.4s
# # highexp_size500_rep75          time=3548.5s
# # highexp_size500_rep76          time=3553.4s
# # highexp_size500_rep77          time=3558.5s
# # highexp_size500_rep78          time=3563.4s
# # highexp_size500_rep79          time=3568.5s
# # highexp_size500_rep80          time=3573.7s
# # highexp_size500_rep81          time=3578.8s
# # highexp_size500_rep82          time=3583.7s
# # highexp_size500_rep83          time=3588.8s
# # highexp_size500_rep84          time=3593.6s
# # highexp_size500_rep85          time=3598.8s
# # highexp_size500_rep86          time=3603.9s
# # highexp_size500_rep87          time=3608.8s
# # highexp_size500_rep88          time=3613.9s
# # highexp_size500_rep89          time=3619.1s
# # highexp_size500_rep90          time=3624.0s
# # highexp_size500_rep91          time=3628.8s
# # highexp_size500_rep92          time=3633.8s
# # highexp_size500_rep93          time=3638.6s
# # highexp_size500_rep94          time=3643.8s
# # highexp_size500_rep95          time=3648.7s
# # highexp_size500_rep96          time=3653.6s
# # highexp_size500_rep97          time=3658.5s
# # highexp_size500_rep98          time=3663.4s
# # highexp_size500_rep99          time=3668.2s
# # lowexp_size100_rep0            time=3673.4s
# # lowexp_size100_rep1            time=3676.9s
# # lowexp_size100_rep2            time=3680.4s
# # lowexp_size100_rep3            time=3683.9s
# # lowexp_size100_rep4            time=3687.3s
# # lowexp_size100_rep5            time=3690.8s
# # lowexp_size100_rep6            time=3694.2s
# # lowexp_size100_rep7            time=3697.7s
# # lowexp_size100_rep8            time=3701.2s
# # lowexp_size100_rep9            time=3704.6s
# # lowexp_size100_rep10           time=3708.1s
# # lowexp_size100_rep11           time=3711.6s
# # lowexp_size100_rep12           time=3715.1s
# # lowexp_size100_rep13           time=3718.6s
# # lowexp_size100_rep14           time=3722.1s
# # lowexp_size100_rep15           time=3725.5s
# # lowexp_size100_rep16           time=3729.0s
# # lowexp_size100_rep17           time=3732.5s
# # lowexp_size100_rep18           time=3736.0s
# # lowexp_size100_rep19           time=3739.4s
# # lowexp_size100_rep20           time=3742.9s
# # lowexp_size100_rep21           time=3746.4s
# # lowexp_size100_rep22           time=3749.9s
# # lowexp_size100_rep23           time=3753.4s
# # lowexp_size100_rep24           time=3756.8s
# # lowexp_size100_rep25           time=3760.3s
# # lowexp_size100_rep26           time=3763.8s
# # lowexp_size100_rep27           time=3767.2s
# # lowexp_size100_rep28           time=3770.7s
# # lowexp_size100_rep29           time=3774.2s
# # lowexp_size100_rep30           time=3777.7s
# # lowexp_size100_rep31           time=3781.1s
# # lowexp_size100_rep32           time=3784.6s
# # lowexp_size100_rep33           time=3788.1s
# # lowexp_size100_rep34           time=3791.6s
# # lowexp_size100_rep35           time=3795.0s
# # lowexp_size100_rep36           time=3798.5s
# # lowexp_size100_rep37           time=3802.0s
# # lowexp_size100_rep38           time=3805.5s
# # lowexp_size100_rep39           time=3809.0s
# # lowexp_size100_rep40           time=3812.5s
# # lowexp_size100_rep41           time=3816.0s
# # lowexp_size100_rep42           time=3819.4s
# # lowexp_size100_rep43           time=3822.9s
# # lowexp_size100_rep44           time=3826.4s
# # lowexp_size100_rep45           time=3829.9s
# # lowexp_size100_rep46           time=3833.4s
# # lowexp_size100_rep47           time=3836.8s
# # lowexp_size100_rep48           time=3840.3s
# # lowexp_size100_rep49           time=3843.8s
# # lowexp_size100_rep50           time=3847.3s
# # lowexp_size100_rep51           time=3850.7s
# # lowexp_size100_rep52           time=3854.2s
# # lowexp_size100_rep53           time=3857.7s
# # lowexp_size100_rep54           time=3861.2s
# # lowexp_size100_rep55           time=3864.6s
# # lowexp_size100_rep56           time=3868.1s
# # lowexp_size100_rep57           time=3871.6s
# # lowexp_size100_rep58           time=3875.1s
# # lowexp_size100_rep59           time=3878.6s
# # lowexp_size100_rep60           time=3882.1s
# # lowexp_size100_rep61           time=3885.6s
# # lowexp_size100_rep62           time=3889.1s
# # lowexp_size100_rep63           time=3892.5s
# # lowexp_size100_rep64           time=3896.0s
# # lowexp_size100_rep65           time=3899.5s
# # lowexp_size100_rep66           time=3902.9s
# # lowexp_size100_rep67           time=3906.4s
# # lowexp_size100_rep68           time=3909.9s
# # lowexp_size100_rep69           time=3913.4s
# # lowexp_size100_rep70           time=3916.8s
# # lowexp_size100_rep71           time=3920.2s
# # lowexp_size100_rep72           time=3923.7s
# # lowexp_size100_rep73           time=3927.2s
# # lowexp_size100_rep74           time=3930.6s
# # lowexp_size100_rep75           time=3934.1s
# # lowexp_size100_rep76           time=3937.5s
# # lowexp_size100_rep77           time=3941.0s
# # lowexp_size100_rep78           time=3944.5s
# # lowexp_size100_rep79           time=3947.9s
# # lowexp_size100_rep80           time=3951.4s
# # lowexp_size100_rep81           time=3954.8s
# # lowexp_size100_rep82           time=3958.3s
# # lowexp_size100_rep83           time=3961.8s
# # lowexp_size100_rep84           time=3965.2s
# # lowexp_size100_rep85           time=3968.7s
# # lowexp_size100_rep86           time=3972.2s
# # lowexp_size100_rep87           time=3975.6s
# # lowexp_size100_rep88           time=3979.0s
# # lowexp_size100_rep89           time=3982.5s
# # lowexp_size100_rep90           time=3986.0s
# # lowexp_size100_rep91           time=3989.4s
# # lowexp_size100_rep92           time=3993.0s
# # lowexp_size100_rep93           time=3996.4s
# # lowexp_size100_rep94           time=3999.9s
# # lowexp_size100_rep95           time=4003.4s
# # lowexp_size100_rep96           time=4006.9s
# # lowexp_size100_rep97           time=4010.3s
# # lowexp_size100_rep98           time=4013.8s
# # lowexp_size100_rep99           time=4017.3s
# # lowexp_size20_rep0             time=4020.8s
# # lowexp_size20_rep1             time=4024.1s
# # lowexp_size20_rep2             time=4027.4s
# # lowexp_size20_rep3             time=4030.7s
# # lowexp_size20_rep4             time=4034.0s
# # lowexp_size20_rep5             time=4037.3s
# # lowexp_size20_rep6             time=4040.6s
# # lowexp_size20_rep7             time=4043.8s
# # lowexp_size20_rep8             time=4047.1s
# # lowexp_size20_rep9             time=4050.4s
# # lowexp_size20_rep10            time=4053.7s
# # lowexp_size20_rep11            time=4057.1s
# # lowexp_size20_rep12            time=4060.4s
# # lowexp_size20_rep13            time=4063.6s
# # lowexp_size20_rep14            time=4066.9s
# # lowexp_size20_rep15            time=4070.2s
# # lowexp_size20_rep16            time=4073.5s
# # lowexp_size20_rep17            time=4076.8s
# # lowexp_size20_rep18            time=4080.0s
# # lowexp_size20_rep19            time=4083.3s
# # lowexp_size20_rep20            time=4086.6s
# # lowexp_size20_rep21            time=4089.9s
# # lowexp_size20_rep22            time=4093.2s
# # lowexp_size20_rep23            time=4096.5s
# # lowexp_size20_rep24            time=4099.9s
# # lowexp_size20_rep25            time=4103.2s
# # lowexp_size20_rep26            time=4106.5s
# # lowexp_size20_rep27            time=4109.8s
# # lowexp_size20_rep28            time=4113.1s
# # lowexp_size20_rep29            time=4116.4s
# # lowexp_size20_rep30            time=4119.6s
# # lowexp_size20_rep31            time=4122.9s
# # lowexp_size20_rep32            time=4126.2s
# # lowexp_size20_rep33            time=4129.5s
# # lowexp_size20_rep34            time=4132.7s
# # lowexp_size20_rep35            time=4136.0s
# # lowexp_size20_rep36            time=4139.3s
# # lowexp_size20_rep37            time=4142.6s
# # lowexp_size20_rep38            time=4145.8s
# # lowexp_size20_rep39            time=4149.1s
# # lowexp_size20_rep40            time=4152.4s
# # lowexp_size20_rep41            time=4155.7s
# # lowexp_size20_rep42            time=4158.9s
# # lowexp_size20_rep43            time=4162.2s
# # lowexp_size20_rep44            time=4165.5s
# # lowexp_size20_rep45            time=4168.8s
# # lowexp_size20_rep46            time=4172.0s
# # lowexp_size20_rep47            time=4175.3s
# # lowexp_size20_rep48            time=4178.6s
# # lowexp_size20_rep49            time=4181.9s
# # lowexp_size20_rep50            time=4185.1s
# # lowexp_size20_rep51            time=4188.4s
# # lowexp_size20_rep52            time=4191.7s
# # lowexp_size20_rep53            time=4195.0s
# # lowexp_size20_rep54            time=4198.4s
# # lowexp_size20_rep55            time=4201.7s
# # lowexp_size20_rep56            time=4205.0s
# # lowexp_size20_rep57            time=4208.3s
# # lowexp_size20_rep58            time=4211.6s
# # lowexp_size20_rep59            time=4214.9s
# # lowexp_size20_rep60            time=4218.2s
# # lowexp_size20_rep61            time=4221.5s
# # lowexp_size20_rep62            time=4224.8s
# # lowexp_size20_rep63            time=4228.0s
# # lowexp_size20_rep64            time=4231.4s
# # lowexp_size20_rep65            time=4234.6s
# # lowexp_size20_rep66            time=4237.9s
# # lowexp_size20_rep67            time=4241.2s
# # lowexp_size20_rep68            time=4244.5s
# # lowexp_size20_rep69            time=4247.8s
# # lowexp_size20_rep70            time=4251.2s
# # lowexp_size20_rep71            time=4254.5s
# # lowexp_size20_rep72            time=4257.8s
# # lowexp_size20_rep73            time=4261.0s
# # lowexp_size20_rep74            time=4264.3s
# # lowexp_size20_rep75            time=4267.6s
# # lowexp_size20_rep76            time=4271.0s
# # lowexp_size20_rep77            time=4274.3s
# # lowexp_size20_rep78            time=4277.6s
# # lowexp_size20_rep79            time=4280.9s
# # lowexp_size20_rep80            time=4284.2s
# # lowexp_size20_rep81            time=4287.5s
# # lowexp_size20_rep82            time=4290.8s
# # lowexp_size20_rep83            time=4294.1s
# # lowexp_size20_rep84            time=4297.4s
# # lowexp_size20_rep85            time=4300.7s
# # lowexp_size20_rep86            time=4304.0s
# # lowexp_size20_rep87            time=4307.2s
# # lowexp_size20_rep88            time=4310.5s
# # lowexp_size20_rep89            time=4313.8s
# # lowexp_size20_rep90            time=4317.0s
# # lowexp_size20_rep91            time=4320.4s
# # lowexp_size20_rep92            time=4323.6s
# # lowexp_size20_rep93            time=4326.9s
# # lowexp_size20_rep94            time=4330.3s
# # lowexp_size20_rep95            time=4333.6s
# # lowexp_size20_rep96            time=4337.0s
# # lowexp_size20_rep97            time=4340.3s
# # lowexp_size20_rep98            time=4343.5s
# # lowexp_size20_rep99            time=4346.8s
# # lowexp_size500_rep0            time=4350.2s
# # lowexp_size500_rep1            time=4353.8s
# # lowexp_size500_rep2            time=4357.3s
# # lowexp_size500_rep3            time=4360.8s
# # lowexp_size500_rep4            time=4364.4s
# # lowexp_size500_rep5            time=4367.9s
# # lowexp_size500_rep6            time=4371.5s
# # lowexp_size500_rep7            time=4375.1s
# # lowexp_size500_rep8            time=4378.7s
# # lowexp_size500_rep9            time=4382.2s
# # lowexp_size500_rep10           time=4385.8s
# # lowexp_size500_rep11           time=4389.4s
# # lowexp_size500_rep12           time=4392.9s
# # lowexp_size500_rep13           time=4396.5s
# # lowexp_size500_rep14           time=4400.0s
# # lowexp_size500_rep15           time=4403.6s
# # lowexp_size500_rep16           time=4407.1s
# # lowexp_size500_rep17           time=4410.6s
# # lowexp_size500_rep18           time=4414.1s
# # lowexp_size500_rep19           time=4417.7s
# # lowexp_size500_rep20           time=4421.2s
# # lowexp_size500_rep21           time=4424.7s
# # lowexp_size500_rep22           time=4428.2s
# # lowexp_size500_rep23           time=4431.7s
# # lowexp_size500_rep24           time=4435.2s
# # lowexp_size500_rep25           time=4438.8s
# # lowexp_size500_rep26           time=4442.3s
# # lowexp_size500_rep27           time=4445.8s
# # lowexp_size500_rep28           time=4449.3s
# # lowexp_size500_rep29           time=4452.8s
# # lowexp_size500_rep30           time=4456.3s
# # lowexp_size500_rep31           time=4459.8s
# # lowexp_size500_rep32           time=4463.3s
# # lowexp_size500_rep33           time=4466.8s
# # lowexp_size500_rep34           time=4470.4s
# # lowexp_size500_rep35           time=4473.9s
# # lowexp_size500_rep36           time=4477.4s
# # lowexp_size500_rep37           time=4480.9s
# # lowexp_size500_rep38           time=4484.4s
# # lowexp_size500_rep39           time=4487.9s
# # lowexp_size500_rep40           time=4491.5s
# # lowexp_size500_rep41           time=4495.0s
# # lowexp_size500_rep42           time=4498.5s
# # lowexp_size500_rep43           time=4502.0s
# # lowexp_size500_rep44           time=4505.5s
# # lowexp_size500_rep45           time=4509.0s
# # lowexp_size500_rep46           time=4512.5s
# # lowexp_size500_rep47           time=4516.1s
# # lowexp_size500_rep48           time=4519.6s
# # lowexp_size500_rep49           time=4523.1s
# # lowexp_size500_rep50           time=4526.6s
# # lowexp_size500_rep51           time=4530.1s
# # lowexp_size500_rep52           time=4533.6s
# # lowexp_size500_rep53           time=4537.2s
# # lowexp_size500_rep54           time=4540.7s
# # lowexp_size500_rep55           time=4544.2s
# # lowexp_size500_rep56           time=4547.7s
# # lowexp_size500_rep57           time=4551.2s
# # lowexp_size500_rep58           time=4554.7s
# # lowexp_size500_rep59           time=4558.2s
# # lowexp_size500_rep60           time=4561.8s
# # lowexp_size500_rep61           time=4565.3s
# # lowexp_size500_rep62           time=4568.8s
# # lowexp_size500_rep63           time=4572.3s
# # lowexp_size500_rep64           time=4575.8s
# # lowexp_size500_rep65           time=4579.3s
# # lowexp_size500_rep66           time=4582.9s
# # lowexp_size500_rep67           time=4586.4s
# # lowexp_size500_rep68           time=4589.9s
# # lowexp_size500_rep69           time=4593.5s
# # lowexp_size500_rep70           time=4597.0s
# # lowexp_size500_rep71           time=4600.5s
# # lowexp_size500_rep72           time=4604.0s
# # lowexp_size500_rep73           time=4607.5s
# # lowexp_size500_rep74           time=4611.0s
# # lowexp_size500_rep75           time=4614.5s
# # lowexp_size500_rep76           time=4618.1s
# # lowexp_size500_rep77           time=4621.6s
# # lowexp_size500_rep78           time=4625.1s
# # lowexp_size500_rep79           time=4628.6s
# # lowexp_size500_rep80           time=4632.1s
# # lowexp_size500_rep81           time=4635.7s
# # lowexp_size500_rep82           time=4639.2s
# # lowexp_size500_rep83           time=4642.7s
# # lowexp_size500_rep84           time=4646.2s
# # lowexp_size500_rep85           time=4649.8s
# # lowexp_size500_rep86           time=4653.3s
# # lowexp_size500_rep87           time=4656.8s
# # lowexp_size500_rep88           time=4660.3s
# # lowexp_size500_rep89           time=4663.9s
# # lowexp_size500_rep90           time=4667.4s
# # lowexp_size500_rep91           time=4670.9s
# # lowexp_size500_rep92           time=4674.4s
# # lowexp_size500_rep93           time=4678.0s
# # lowexp_size500_rep94           time=4681.5s
# # lowexp_size500_rep95           time=4685.0s
# # lowexp_size500_rep96           time=4688.6s
# # lowexp_size500_rep97           time=4692.1s
# # lowexp_size500_rep98           time=4695.6s
# # lowexp_size500_rep99           time=4699.1s

# %%
import pickle
DATA_PATH='/n/holystore01/LABS/price_lab/Users/mjzhang/scTRS_data'
with open(DATA_PATH+'/data_null_geneset/simu_result/res_config_subset.100320.pickle','wb') as f:
    pickle.dump(dic_trs,f)

# %%
# # Check if the results between two runs are consistent 
# import pickle
# DATA_PATH='/n/holystore01/LABS/price_lab/Users/mjzhang/scTRS_data'
# with open(DATA_PATH+'/data_null_geneset/simu_result/res_config_subset.100320.pickle', 'rb') as f:
#     dic_trs_ref = pickle.load(f)
    
# for term in list(dic_trs.keys())[0:10]:
#     print('# %-30s dif=%0.2e'%(term, np.absolute(dic_trs[term]-dic_trs_ref[term]).sum()))
# Out:
# # all_size100_rep0_equal;ctrl_opt=mean_match,trs_opt=mean,bc_opt=empi dif=0.00e+00
# # all_size100_rep0_unif;ctrl_opt=mean_match,trs_opt=mean,bc_opt=empi dif=0.00e+00
# # all_size100_rep0_norm;ctrl_opt=mean_match,trs_opt=mean,bc_opt=empi dif=0.00e+00
# # all_size100_rep0_equal;ctrl_opt=mean_match,trs_opt=mean,bc_opt=recipe_vision dif=0.00e+00
# # all_size100_rep0_unif;ctrl_opt=mean_match,trs_opt=mean,bc_opt=recipe_vision dif=0.00e+00
# # all_size100_rep0_norm;ctrl_opt=mean_match,trs_opt=mean,bc_opt=recipe_vision dif=0.00e+00
# # all_size100_rep0_equal;ctrl_opt=mean_match,trs_opt=vst,bc_opt=empi dif=0.00e+00
# # all_size100_rep0_unif;ctrl_opt=mean_match,trs_opt=vst,bc_opt=empi dif=0.00e+00
# # all_size100_rep0_norm;ctrl_opt=mean_match,trs_opt=vst,bc_opt=empi dif=0.00e+00
# # all_size100_rep0_equal;ctrl_opt=mean_match,trs_opt=vst,bc_opt=recipe_vision dif=0.00e+00

# %% [markdown]
# ### Make figure

# %%
import pickle
DATA_PATH='/n/holystore01/LABS/price_lab/Users/mjzhang/scTRS_data'
with open(DATA_PATH+'/data_null_geneset/simu_result/res_config_subset.100320.pickle', 'rb') as f:
    dic_trs = pickle.load(f)

# %%
import re
md_list = list(set([x.split(';')[1] for x in dic_trs.keys()]))
md_list.sort()

trait_list = list(set([x.split(';')[0].replace('_rep0','')
                   for x in dic_trs.keys() if '_rep0_' in x]))
trait_list.sort()

df_plot = pd.DataFrame(columns=['%s.mean.5en2'%x for x in trait_list] + ['%s.se.5en2'%x for x in trait_list] + 
                               ['%s.mean.5en3'%x for x in trait_list] + ['%s.se.5en3'%x for x in trait_list] + 
                               ['%s.mean.5en4'%x for x in trait_list] + ['%s.se.5en4'%x for x in trait_list],
                       index=md_list, data=-1)

for trait in trait_list:
    for mname in md_list:
        v_nrej_5en2 = []
        v_nrej_5en3 = []
        v_nrej_5en4 = []
        for term in [x for x in dic_trs.keys() 
                     if (re.sub('_rep[0-9]+_','_',x.split(';')[0])==trait)&(x.split(';')[1]==mname)]:
            v_p = dic_trs[term]
            v_nrej_5en2.append((v_p<5e-2).mean())
            v_nrej_5en3.append((v_p<5e-3).mean())
            v_nrej_5en4.append((v_p<5e-4).mean())
        v_nrej_5en2 = np.array(v_nrej_5en2)
        v_nrej_5en3 = np.array(v_nrej_5en3)
        v_nrej_5en4 = np.array(v_nrej_5en4)
        df_plot.loc[mname, '%s.mean.5en2'%trait] = v_nrej_5en2.mean()
        df_plot.loc[mname, '%s.se.5en2'%trait] = v_nrej_5en2.std()/np.sqrt(v_nrej_5en2.shape[0])
        df_plot.loc[mname, '%s.mean.5en3'%trait] = v_nrej_5en3.mean()
        df_plot.loc[mname, '%s.se.5en3'%trait] = v_nrej_5en3.std()/np.sqrt(v_nrej_5en3.shape[0])
        df_plot.loc[mname, '%s.mean.5en4'%trait] = v_nrej_5en4.mean()
        df_plot.loc[mname, '%s.se.5en4'%trait] = v_nrej_5en4.std()/np.sqrt(v_nrej_5en4.shape[0])
#         break
#     break
    print(trait)
# Out:
# all_size100_equal
# all_size100_norm
# all_size100_unif
# all_size20_equal
# all_size20_norm
# all_size20_unif
# all_size500_equal
# all_size500_norm
# all_size500_unif
# highexp_size100_equal
# highexp_size100_norm
# highexp_size100_unif
# highexp_size20_equal
# highexp_size20_norm
# highexp_size20_unif
# highexp_size500_equal
# highexp_size500_norm
# highexp_size500_unif
# lowexp_size100_equal
# lowexp_size100_norm
# lowexp_size100_unif
# lowexp_size20_equal
# lowexp_size20_norm
# lowexp_size20_unif
# lowexp_size500_equal
# lowexp_size500_norm
# lowexp_size500_unif

# %%
trait_list = ['all_size20', 'all_size100', 'all_size500',
              'lowexp_size20', 'lowexp_size100', 'lowexp_size500',
              'highexp_size20', 'highexp_size100', 'highexp_size500']
dic_weight_name = {'equal':'Equal weights', 'unif':'Uniform weights', 'norm':'Normal weights'}

# trait_list = ['%s_equal'%x for x in trait_list] + ['%s_unif'%x for x in trait_list] \
#                 + ['%s_norm'%x for x in trait_list]

md_list = ['ctrl_opt=mean_match,trs_opt=mean,bc_opt=empi',
           'ctrl_opt=mean_match,trs_opt=mean,bc_opt=recipe_vision',
           'ctrl_opt=mean_match,trs_opt=vst,bc_opt=empi',
           'ctrl_opt=mean_match,trs_opt=vst,bc_opt=recipe_vision']

for mname in md_list:
    
    plt.figure(figsize=[10,6])
    
    for i_cutoff,cutoff in enumerate([2,3,4]):
        
        thres = 5*10**(-cutoff)
        
        for i_weight_opt,weight_opt in enumerate(['equal', 'unif', 'norm']):
            
            trait_w_list = ['%s_%s'%(x,weight_opt) for x in trait_list]
            plt.subplot(3,3,i_cutoff*3+i_weight_opt+1)
            plt.bar(range(len(trait_w_list)), df_plot.loc[mname, ['%s.mean.5en%d'%(x,cutoff) for x in trait_w_list]], 
                    alpha=0.6)
            plt.errorbar(range(len(trait_w_list)), df_plot.loc[mname, ['%s.mean.5en%d'%(x,cutoff) for x in trait_w_list]],
                         yerr=1.96*df_plot.loc[mname, ['%s.se.5en%d'%(x,cutoff) for x in trait_w_list]],
                         color='k', fmt='.', label='95% CIs')    
            plt.plot([-0.5, len(trait_w_list)-0.5],[thres, thres], linestyle='--', color='k')
            plt.xlim([-0.5, len(trait_w_list)-0.5])
            max_val = 1.05*df_plot.loc[mname, ['%s.mean.5en%d'%(x,cutoff) for x in trait_w_list]].max()
            plt.ylim([0, max(max_val, 2*thres)] )
            plt.xticks(range(len(trait_w_list)), ['']*len(trait_w_list))
            plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
            plt.grid(linestyle='--')
            
            if (i_weight_opt==0)&(i_cutoff==0):
                plt.legend()
                
            if i_weight_opt==0:
                plt.ylabel('Prop. of cells\nwith p<5e-%d'%cutoff)
        
            if i_cutoff==0:
                plt.title(dic_weight_name[weight_opt])                
            
            if i_cutoff==2:
                plt.xticks(range(len(trait_w_list)), trait_w_list, rotation='45', ha='right')
    
    plt.suptitle(mname)
    plt.tight_layout()
    plt.show()
